# %%
import random




class restro:
    def __init__(self,name):
        self.restroname=name
        self.foodlist={}
        self.food_id = None
        self.ordered_item=[]
        self.personal_details={}
        
        
#admin work

    def additem(self):
        self.foodname= input("Enter the Food name")
        self.quantity= input("Enter the Quantity with ml/kg/grm etc")
        self.price= int(input("Enter the price for the item"))
        self.discount = int(input("Enter the discount to the product"))
        self.stock = int(input("Enter the stock remaining"))
        self.list={"Name":self.foodname,"Quantity":self.quantity,"Price":self.price,"Discount":self.discount,"Stock":self.stock}
        self.food_id =random.randint(0,22)
        self.foodlist[self.food_id]=self.list
        print("Food details updated successfully",self.foodlist)
    def remove_items(self):
        print("Are you sure you want to delete the food item ")
        n=input("press y/n")
        if n=="y":
            self.view_items()
            del self.foodlist[int(input("Enter the food id that you want to delete"))]
            print("items deleted successfully")
            print("Remaining items left are",self.foodlist)
        else:
            print("Item did not deleted by admin")        
    def edit_fooddetails(self):
        self.view_items()
        while True:
            f_id = int(input("Enter the food id for which you want to update"))
            if f_id in self.foodlist.keys():
                xc=int(input("Enter the details for \t 1 Update Name  \t 2 Update quantity \t 3 Update Price \t 4 Update Discount \t 5 Update Stock"))
                if xc==1:
                    m=input(" enter the name to update")
                    self.foodlist[f_id].update({"Name":m})
                    break
                elif xc==2:
                    m=input(" enter the quantity to update")
                    self.foodlist[f_id].update({"Quantity":m})
                    break
                elif xc==3:
                    m=input(" enter the Price to update")
                    self.foodlist[f_id].update({"Price":m})
                    break
                elif xc==4:
                    m=input(" enter the Discount to update")
                    self.foodlist[f_id].update({"Discount":m})
                    break
                elif xc==5:
                    m=input(" enter the Stock to update")
                    self.foodlist[f_id].update({"Stock":m})
                    break
                else:
                    print("CHOOSE CORRECT OPTION!!!!")
            else:
                print("You Have Entered the wrong food id ")
    def view_items(self):
        print(" Lists of all the food items Available in Restro")
        if len(self.foodlist)!=0:
            for u in self.foodlist:
                print("Food Id :" ,u)
                print("Name\t        Quantity\t   Price\t    Discount\t   Stock")
                av=[]
                for j in self.foodlist[u]:
                    val=self.foodlist[u].get(j)
                    av.append(val) 
                print(av[0],"\t   ",av[1],"\t   ",av[2],"\t    ",av[3],"\t   ",av[4])
                print()
        else:
            print("Foods Are Not Prepared for menus display ")
            
            
### User Functions now                
    def User_registerdetails(self):
        while True:
            ss=input("Enter Your First Name ")
            if ss.isalpha():
                uname=ss
                break
            else:
                print("Enter Again")
        while True:
            ls=input("Enter Your last Name ")
            if ls.isalpha():
                lname=ls
                break
            else:
                print("Enter Again")  

        Name_=(uname+""+lname)  
        while True:
            try:
                phone_no=int(input("Enter your 10 digit phone number : "))
                break
            except ValueError:
                print("\nThis is not a number. Try again...")
                print()          
        email=input("Enter your email id : ")
        password=input("Enter your password : ")
        address=input("Enter your address with area PIN code ")
        self.personal_details={"Name":Name_,"Phone No":phone_no,"Email":email,"Password":password,"Address":address}
        print("HURRAY!!!! Your account has been created ")
        print("Please Note your details for loign purpose")
        print("details are as follows :")
        for i in self.personal_details:
            print(i, ":", self.personal_details[i])
            
            
    def user_login(self):
        while True:
            print("*"*10,"Welcome to ",self.restroname,"*"*10)
            print()
            print()
            email=input("Enter Your Email ID : ")
            pas=input("Enter Your Password : ")
            if len(self.personal_details)!=0:
                    if email==self.personal_details["Email"] and pas==self.personal_details["Password"]:
                        print("*"*12,"Login Successfully","*"*12)
                        while True:
                            print("\nEnter the Below Options\n")
                            print("1. Place New Order\n2. Check Order History\n3. Update Your Profile Details\n4. Exit")
                            z=input()
                            if z=="1":
                                self.place_order()
                            elif z=="2":
                                self.order_history()
                            elif z=="3":
                                self.update_details()
                            elif z=="4":
                                break
                            else:
                                print("invalid Number")
                    else:
                        print("You have Entered the wrong emailid password")
            else:
                ("No Accounts Created yet please create a account")
            break   
    def place_order(self):
        if len(self.foodlist)!=0:
            menu=[]
            print("Menu are as given below ")
            for items in self.foodlist:
                menu.append([self.foodlist[items]["Name"],self.foodlist[items]["Quantity"],self.foodlist[items]["Stock"]])
            for i in menu:
                print(i)
            while True:
                print("\t Enter 1 to Place Order \t Enter 2 for Exit")
                x=input()
                if x=="1":
                    print("Enter The food no that you want to order for multiple food order give no with comma separted 'Eg 1,2'")
                    y=input().split(",")
                    for a in y:
                        num=int(a)
                        if num<=len(menu):
                            self.ordered_item.append(menu[num-1])
                            print("Enter 1 to Pay for",menu[num-1])
                            #a=input()
                            while True:
                                a=int(input())
                                if a==1:
                                    print("payment Success Press any e for exit")
                                    l=input()
                                    break
                                else:
                                    print("Please Enter 1 only to pay"menu[num-1])
                        else:
                            print("No Foodlist for the no seleted")
                if x=="2":
                    break
        else:
            print("No Food added in menu sorry")
    def order_history(self):
        print("\n list of Your Order History is")
        for i in self.ordered_item:
            print(i)
    def update_details(self):
        while True:
            print("Select Below Options to Update Your Profile Details\n")
            print("1. Name\n2. Phone number\n3. Email ID\n4. Password\n5. Address\n6. Exit\n")
            x=input()
            if x=="1":
                self.personal_details["Name"]=input("Enter your updated full name : ")
                print("\n!! Detail Updated Successfully !!\n")
            elif x=="2":
                self.personal_details["Phone No"]=int(input("Enter your updated 10 digit phone number : "))
                print("\n!! Detail Updated Successfully !!\n")      
            elif x=="3":
                self.personal_details["Email"]=input("Enter your updated email id : ")
                print("\n!! Detail Updated Successfully !!")
                    
            elif x=="4":
                self.personal_details["Password"]=input("Enter your updated password : ")
                print("\n!! Detail Updated Successfully !!\n")
                    
            elif x=="5":
                self.personal_details["Address"]=input("Enter your updated address with area PIN code ")
                print("\n!! Detail Updated Successfully !!\n")
                    
            elif x=="6":
                break
            else:
                print("\you Entered the Invalid Number Entered .......\n")
                    
            if x in ["1","2","3",'4',"5"]:
                for i in self.personal_details:
                    print(i, ":",self.personal_details[i])
            else:
                print("Please Enter correct input from the above options \n")
#main function                    
def main():
    Res=restro("Aditya'Kitchen")
    print("*"*15,"Welcome to ",Res.restroname,"*"*15)
    print("*"*20)
    while True:
        print("Hello Please Choose the correct option ")
        print("\t 1 Admin \t 2 User \t 3 Exit")
        x=input("")
        if x=="1":
            while True:
                print("Choose the below option")
                print("1 Add Food Item  2 Delete Food Item  3 Edit Food Item  4 View Food Item 5 Exit")
                y=input()
                if y=="1":
                    print("Please Add the Food item")
                    Res.additem()
                elif y=="2":
                    print("Delete Food ")
                    Res.remove_items()
                elif y=="3":
                    print("Edit Food")
                    Res.edit_fooddetails()
                elif y=="4":
                    print("View Food ")
                    Res.view_items()
                elif y=="5":
                    break
                else:
                    print("Wrong Number Selected")
        elif x=="2":
            while True:
                print("Choose The Option below")
                print("\t 1 Register\t 2 login\t 3 exit")
                a=input()
                if a=="1":
                    print("register Yourself")
                    Res.User_registerdetails()
                elif a=="2":
                    print("Login Here")
                    Res.user_login()
                elif a=="3":
                    break
                else:
                    print("Wrong Input")
        elif x=="3":
            break
        else:
            print("Invalid Number")
                
if __name__=='__main__':
    
    main()
    
print("*" * 20)
print("please Visit Again")
# Out:
# *************** Welcome to  Aditya'Kitchen ***************
# ********************
# Hello Please Choose the correct option
# 	 1 Admin 	 2 User 	 3 Exit
# 1
# Choose the below option
# 1 Add Food Item  2 Delete Food Item  3 Edit Food Item  4 View Food Item 5 Exit
# 1
# Please Add the Food item
# Enter the Food nameTandoori Chicken
# Enter the Quantity with ml/kg/grm etc4 Pieces
# Enter the price for the item240
# Enter the discount to the product15
# Enter the stock remaining12
# Food details updated successfully {3: {'Name': 'Tandoori Chicken ', 'Quantity': '4 Pieces', 'Price': 240, 'Discount': 15, 'Stock': 12}}
# Choose the below option
# 1 Add Food Item  2 Delete Food Item  3 Edit Food Item  4 View Food Item 5 Exit
# 1
# Please Add the Food item
# Enter the Food nameVegan Burger
# Enter the Quantity with ml/kg/grm etc1 piece
# Enter the price for the item340
# Enter the discount to the product20
# Enter the stock remaining8
# ...
